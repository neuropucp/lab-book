# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/neuropucp/lab-book/blob/main/book/codigoEDA.ipynb)

# %% [markdown]
# # Análisis de señales EDA

# %% [markdown]
# Instalamos los paquetes necesarios:

# %%
# !pip install neurokit2
# Out:
# Requirement already satisfied: neurokit2 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (0.2.12)
# Requirement already satisfied: requests in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from neurokit2) (2.32.3)
# Requirement already satisfied: numpy in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from neurokit2) (2.3.4)
# Requirement already satisfied: pandas in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from neurokit2) (2.3.3)
# Requirement already satisfied: scipy in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from neurokit2) (1.16.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from neurokit2) (1.7.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from neurokit2) (3.10.7)
# Requirement already satisfied: PyWavelets>=1.4.0 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from neurokit2) (1.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from matplotlib>=3.5.0->neurokit2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from matplotlib>=3.5.0->neurokit2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from matplotlib>=3.5.0->neurokit2) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from matplotlib>=3.5.0->neurokit2) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from matplotlib>=3.5.0->neurokit2) (25.0)
# Requirement already satisfied: pillow>=8 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from matplotlib>=3.5.0->neurokit2) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from matplotlib>=3.5.0->neurokit2) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from matplotlib>=3.5.0->neurokit2) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from scikit-learn>=1.0.0->neurokit2) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from scikit-learn>=1.0.0->neurokit2) (3.6.0)
# Requirement already satisfied: pytz>=2020.1 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from pandas->neurokit2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from pandas->neurokit2) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from requests->neurokit2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from requests->neurokit2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from requests->neurokit2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from requests->neurokit2) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->neurokit2) (1.17.0)

# %% [markdown]
# Para este tutorial usaremos datos EDA extraidos con el sistema Nuanic:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/neuropucp/lab-book/refs/heads/main/res/nuanic-sample.csv")
df = df[df.eda.isin([r"\N"]) == False]
df["eda"] = pd.to_numeric(df["eda"])
df
# Out:
#      address   time_unix                        time dne srl srrn     eda
# 0    RP01006  1710921858    2024-03-20 08:04:17.7+00  \N  \N   \N  691471
# 1    RP01006  1710921858  2024-03-20 08:04:18.033+00  \N  \N   \N  691471
# 2    RP01006  1710921858  2024-03-20 08:04:18.366+00  \N  \N   \N  636675
# 3    RP01006  1710921859  2024-03-20 08:04:18.699+00  \N  \N   \N  638482
# 4    RP01006  1710921859  2024-03-20 08:04:19.032+00  \N  \N   \N  623489
# ..       ...         ...                         ...  ..  ..  ...     ...
# 755  RP01006  1710922109  2024-03-20 08:08:29.134+00  \N  \N   \N  545832
# 756  RP01006  1710922109  2024-03-20 08:08:29.467+00  \N  \N   \N  546271
# 757  RP01006  1710922110    2024-03-20 08:08:29.8+00  \N  \N   \N  546858
# 758  RP01006  1710922110  2024-03-20 08:08:30.143+00  \N  \N   \N  545539
# 759  RP01006  1710922110  2024-03-20 08:08:30.476+00  \N  \N   \N  543492
#
# [760 rows x 7 columns]

# %% [markdown]
# Visualizamos los datos:

# %%
import seaborn as sns

sns.lineplot(x="time_unix", y="eda", data=df)
# Out:
# <Axes: xlabel='time_unix', ylabel='eda'>

# %% [markdown]
# Ejecutamos el pipeline básico de Neurokit 2 para preprocesar señales EDA (`eda_process`):

# %%
import neurokit2 as nk

eda_signal = df.eda
signals, info = nk.eda_process(eda_signal, sampling_rate=3, method="neurokit")
# Out:
# /home/renato-paredes/.virtualenvs/neuropucp-book/lib/python3.11/site-packages/neurokit2/eda/eda_clean.py:105: NeuroKitWarning: EDA signal is sampled at very low frequency. Skipping filtering.
#   warn(

# %% [markdown]
# Obtenemos los indicadores de la señal:

# %%
signals
# Out:
#      EDA_Raw  EDA_Clean      EDA_Tonic    EDA_Phasic  SCR_Onsets  SCR_Peaks  \
# 0     691471     691471  687455.100896   4015.899104           0          0
# 1     691471     691471  679136.588654  12334.411346           0          1
# 2     636675     636675  670828.936886 -34153.936886           1          0
# 3     638482     638482  662584.010933 -24102.010933           0          1
# 4     623489     623489  654451.571895 -30962.571895           0          0
# ..       ...        ...            ...           ...         ...        ...
# 755   545832     545832  540423.042406   4079.092162           0          0
# 756   546271     546271  540726.655949   4021.481218           0          0
# 757   546858     546858  540985.584887   4143.764348           0          0
# 758   545539     545539  541202.428315   2389.735389           0          0
# 759   543492     543492  541380.406010    -65.223113           0          0
#
#        SCR_Height  SCR_Amplitude  SCR_RiseTime  SCR_Recovery  SCR_RecoveryTime
# 0        0.000000       0.000000      0.000000             0          0.000000
# 1    12334.411346            NaN           NaN             0          0.000000
# 2        0.000000       0.000000      0.000000             0          0.000000
# 3   -24102.010933   10051.925954      0.333333             0          0.000000
# 4        0.000000       0.000000      0.000000             1          0.333333
# ..            ...            ...           ...           ...               ...
# 755      0.000000       0.000000      0.000000             0          0.000000
# 756      0.000000       0.000000      0.000000             0          0.000000
# 757      0.000000       0.000000      0.000000             0          0.000000
# 758      0.000000       0.000000      0.000000             0          0.000000
# 759      0.000000       0.000000      0.000000             0          0.000000
#
# [760 rows x 11 columns]

# %% [markdown]
# Y la información relevante a analizar:

# %%
info
# Out:
# {'SCR_Onsets': array([ nan,   2.,  10.,  33., 350., 378., 424., 450., 473., 496., 522.,
#         572., 612., 629., 642., 676.]),
#  'SCR_Peaks': array([  1,   3,  27,  41, 365, 380, 438, 461, 479, 498, 525, 593, 620,
#         633, 657, 691]),
#  'SCR_Height': array([ 12334.41134572, -24102.01093259,   8602.53410696,   7449.97443911,
#          29111.04292567,  16716.72896096,  39488.53276245,  33557.95909724,
#          -3785.74033518,   6299.49014949,   7393.10553502,  39410.43896695,
#          31413.99391585,  24750.9793251 ,   7730.75412583,   4872.6094852 ]),
#  'SCR_Amplitude': array([           nan, 10051.92595386, 46906.50578902,  8570.82998681,
#         33279.36494728,  2421.54173114, 34249.62697203, 68700.14855417,
#         17292.45339844,   924.2458249 ,  1374.7421041 , 42022.77049001,
#         54310.35764891, 34536.39006737, 38760.03720946,  7936.73621127]),
#  'SCR_RiseTime': array([       nan, 0.33333333, 5.66666667, 2.66666667, 5.        ,
#         0.66666667, 4.66666667, 3.66666667, 2.        , 0.66666667,
#         1.        , 7.        , 2.66666667, 1.33333333, 5.        ,
#         5.        ]),
#  'SCR_Recovery': array([ nan,   4.,  nan,  85.,  nan, 381., 441., 471., 481., 499., 530.,
#         596., 625., 639.,  nan, 695.]),
#  'SCR_RecoveryTime': array([        nan,  0.33333333,         nan, 14.66666667,         nan,
#          0.33333333,  1.        ,  3.33333333,  0.66666667,  0.33333333,
#          1.66666667,  1.        ,  1.66666667,  2.        ,         nan,
#          1.33333333]),
#  'sampling_rate': 3}

# %% [markdown]
# Podemos visualizar el resultado de nuestro pre-procesamiento con visualización por defecto del paquete (`eda_plot`):

# %%
nk.eda_plot(signals, info)

# %% [markdown]
# Y podemos calcular métricas relevantes de la señal con las función `eda_analyze`:

# %%
analyze_df = nk.eda_analyze(signals, sampling_rate=3, method="interval-related")
analyze_df
# Out:
#    SCR_Peaks_N  SCR_Peaks_Amplitude_Mean  EDA_Tonic_SD  EDA_Sympathetic  \
# 0         16.0              26755.845126  160554.02827     1.616763e+08
#
#    EDA_SympatheticN  EDA_Autocorrelation
# 0          0.001971             0.972385
